# %%
# IMPORTING ALL THE LIBRARIES NEEDED
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import PIL
from PIL import Image

# %%
# OPENING THE IMAGES FROM THE LOCATION(IF THE IMAGES HAVE CONTINOUS NUMBERS AS NAMES, FOR LOOP CAN BE USED HERE)
img1=Image.open('C:/Users/nobody/Desktop/cat/cat1.jpg')
img2=Image.open('C:/Users/nobody/Desktop/cat/cat2.jpg')
img3=Image.open('C:/Users/nobody/Desktop/cat/cat3.jpg')
img4=Image.open('C:/Users/nobody/Desktop/cat/cat4.jpg')
img5=Image.open('C:/Users/nobody/Desktop/cat/cat5.jpg')

# %%
# PLOTTING THE IMAGES AS SUBPLOTS
fig=plt.figure(figsize=(16,16))
plt.figure(1)
plt.subplot(511)
plt.imshow(img1)
plt.subplot(512)
plt.imshow(img2)
plt.subplot(513)
plt.imshow(img3)
plt.subplot(514)
plt.imshow(img4)
plt.subplot(515)
plt.imshow(img5)

# %%
# WE CAN DO IT IN ANOTHER WAY USING 'add_subplot'
figA = plt.figure(figsize=(12,12))
ax1 = figA.add_subplot(2,2,1)
ax1.imshow(img1)
ax2 = figA.add_subplot(2,2,2)
ax2.imshow(img2)
ax3 = figA.add_subplot(2,2,3)
ax3.imshow(img3)
ax4 = figA.add_subplot(2,2,4)
ax4.imshow(img4)

# %%
# PLOTTING IMAGE INSIDE IMAGE INSIDE IMAGE....
figA = plt.figure()
ax1 = figA.add_subplot(1,1,1)
ax1.imshow(img1)
ax2 = figA.add_subplot(2,2,2)
ax2.imshow(img1)
ax3 = figA.add_subplot(3,3,3)
ax3.imshow(img1)
ax4 = figA.add_subplot(4,4,4)
ax4.imshow(img1)
ax4 = figA.add_subplot(5,5,5)
ax4.imshow(img1)
ax4 = figA.add_subplot(6,6,6)
ax4.imshow(img1)
ax4 = figA.add_subplot(7,7,7)
ax4.imshow(img1)
plt.title('PLOT INSIDE PLOT INSIDE PLOT                                  '        ,fontsize=24)
# Out:
# Text(0.5, 1.0, 'PLOT INSIDE PLOT INSIDE PLOT                                  ')

# %%
figA = plt.figure(figsize=(10,6))
ax1 = figA.add_subplot(1,1,1)
ax1.imshow(img3)
ax2 = figA.add_subplot(2,2,2)
ax2.imshow(img3)
ax3 = figA.add_subplot(3,3,3)
ax3.imshow(img3)
ax4 = figA.add_subplot(4,4,4)
ax4.imshow(img3)
ax4 = figA.add_subplot(5,5,5)
ax4.imshow(img3)
ax4 = figA.add_subplot(6,6,6)
ax4.imshow(img3)
ax4 = figA.add_subplot(7,7,7)
ax4.imshow(img3)
plt.title(' CUTE CATS                           ',fontsize=60)
# Out:
# Text(0.5, 1.0, ' CUTE CATS                           ')

# %%
imgcat = Image.open("C:/Users/nobody/Desktop/cat/cat1.jpg") 
imgcat1 = img.convert("L") 
# img1.show() 
imgcat2 = img.convert("1") 
# img2.show() 
# plt.imshow(img)
# img2=img2.save("C:/Users/nobody/Desktop/cat/imgcat.jpg")
figC = plt.figure(figsize=(12,12))
ax1 = figC.add_subplot(4,2,1)
ax1.imshow(imgcat)
ax2 = figC.add_subplot(4,2,2)
ax2.imshow(imgcat2)
ax3 = figC.add_subplot(4,2,3)
ax3.imshow(imgcat)
ax3 = figC.add_subplot(4,2,3)
ax3.imshow(imgcat)
ax4 = figC.add_subplot(4,2,4)
ax4.imshow(imgcat1)
# Out:
# C:\Users\nobody\anaconda3\lib\site-packages\ipykernel_launcher.py:15: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   from ipykernel import kernelapp as app
